# %%
from prediction_helpers import *

ExE = pd.read_csv('../extracted_data/ExE_imputed_5.csv', sep=',', index_col=0)
NxN = pd.read_csv('../extracted_data/NxN_imputed_10.csv', sep=',', index_col=0)
ExN = pd.read_csv('../extracted_data/ExN_filled_20.csv', sep=',', index_col=0)

predictive_model = [ 
    Lasso(alpha=0.0001),
]

random.seed(35)
proportion = 1

# %% [markdown]
# ## ExE

# %%
results_ExE = iterate_over_proportion(ExE, proportion, predictive_model)
print_results(results_ExE)
plot_results(results_ExE)
print_top_genes(results_ExE, 'Lasso')
# Out:
# Model: Lasso
# Average R²:   0.4451
# Average RMSE: 0.0606
# Top 10 Genes by R² Score for Lasso:
#      Gene  R2 Score
# YBL105C.1  0.857201
#   YBL084C  0.815737
#   YLR314C  0.800394
# YDR145W.2  0.800192
#   YDR145W  0.797480
#   YPL076W  0.795879
#   YLR459W  0.794368
# YFR004W.1  0.793130
#   YDR331W  0.790779
#   YFR004W  0.788782
#           Gene  R2 Score
# 510  YBL105C.1  0.857201
# 396    YBL084C  0.815737
# 471    YLR314C  0.800394
# 223  YDR145W.2  0.800192
# 516    YDR145W  0.797480
# 409    YPL076W  0.795879
# 157    YLR459W  0.794368
# 88   YFR004W.1  0.793130
# 425    YDR331W  0.790779
# 480    YFR004W  0.788782

# %% [markdown]
# ## NxN

# %%
results_NxN = iterate_over_proportion(NxN, proportion, predictive_model)
print_results(results_NxN)
plot_results(results_NxN)
print_top_genes(results_NxN, 'Lasso')
# Out:
# Model: Lasso
# Average R²:   0.1724
# Average RMSE: 0.0346
# Top 10 Genes by R² Score for Lasso:
#    Gene  R2 Score
# YDR149C  0.767010
# YHR079C  0.763230
# YDR150W  0.762915
# YFL031W  0.759183
# YNL051W  0.737296
# YML071C  0.730638
# YFL032W  0.730076
# YDR334W  0.729784
# YNL041C  0.724379
# YOL004W  0.720068
#          Gene  R2 Score
# 483   YDR149C  0.767010
# 2949  YHR079C  0.763230
# 661   YDR150W  0.762915
# 83    YFL031W  0.759183
# 2601  YNL051W  0.737296
# 1723  YML071C  0.730638
# 703   YFL032W  0.730076
# 2981  YDR334W  0.729784
# 3141  YNL041C  0.724379
# 812   YOL004W  0.720068

# %% [markdown]
# ## ExN

# %%
results_ExN = iterate_over_proportion(ExE, proportion, predictive_model)
print_results(results_ExN)
plot_results(results_ExN)
print_top_genes(results_ExN, 'Lasso')
# Out:
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/joblib/externals/loky/process_executor.py:752: UserWarning: A worker stopped while some jobs were given to the executor. This can be caused by a too short worker timeout or by a memory leak.
#   warnings.warn(
# Model: Lasso
# Average R²:   0.4451
# Average RMSE: 0.0606
# Top 10 Genes by R² Score for Lasso:
#      Gene  R2 Score
# YBL105C.1  0.857201
#   YBL084C  0.815737
#   YLR314C  0.800394
# YDR145W.2  0.800192
#   YDR145W  0.797480
#   YPL076W  0.795879
#   YLR459W  0.794368
# YFR004W.1  0.793130
#   YDR331W  0.790779
#   YFR004W  0.788782
#           Gene  R2 Score
# 510  YBL105C.1  0.857201
# 396    YBL084C  0.815737
# 471    YLR314C  0.800394
# 223  YDR145W.2  0.800192
# 516    YDR145W  0.797480
# 409    YPL076W  0.795879
# 157    YLR459W  0.794368
# 88   YFR004W.1  0.793130
# 425    YDR331W  0.790779
# 480    YFR004W  0.788782

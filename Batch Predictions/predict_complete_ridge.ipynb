# %%
from prediction_helpers import *

ExE = pd.read_csv('../extracted_data/ExE_imputed_5.csv', sep=',', index_col=0)
NxN = pd.read_csv('../extracted_data/NxN_imputed_10.csv', sep=',', index_col=0)
ExN = pd.read_csv('../extracted_data/ExN_filled_20.csv', sep=',', index_col=0)

predictive_model = [ 
    Ridge(alpha=5),
]

random.seed(35)
proportion = 1

# %% [markdown]
# ## ExE

# %%
results_ExE = iterate_over_proportion(ExE, proportion, predictive_model)
print_results(results_ExE)
plot_results(results_ExE)
print_top_genes(results_ExE, 'Ridge')
# Out:
# Model: Ridge
# Average R²:   0.4612
# Average RMSE: 0.0601
# Top 10 Genes by R² Score for Ridge:
#      Gene  R2 Score
#   YBL084C  0.810951
# YDR145W.2  0.805389
# YBL105C.1  0.790915
#   YHR188C  0.785961
# YJR076C.3  0.774518
#   YDR331W  0.771438
#   YLR314C  0.770758
# YCR002C.1  0.768029
#   YLR459W  0.763090
# YJR076C.4  0.762542
#           Gene  R2 Score
# 396    YBL084C  0.810951
# 223  YDR145W.2  0.805389
# 510  YBL105C.1  0.790915
# 173    YHR188C  0.785961
# 460  YJR076C.3  0.774518
# 425    YDR331W  0.771438
# 471    YLR314C  0.770758
# 195  YCR002C.1  0.768029
# 157    YLR459W  0.763090
# 606  YJR076C.4  0.762542

# %% [markdown]
# ## NxN

# %%
results_NxN = iterate_over_proportion(NxN, proportion, predictive_model)
print_results(results_NxN)
plot_results(results_NxN)
print_top_genes(results_NxN, 'Ridge')
# Out:
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/joblib/externals/loky/process_executor.py:752: UserWarning: A worker stopped while some jobs were given to the executor. This can be caused by a too short worker timeout or by a memory leak.
#   warnings.warn(
# Model: Ridge
# Average R²:   0.2094
# Average RMSE: 0.0340
# Top 10 Genes by R² Score for Ridge:
#    Gene  R2 Score
# YFL031W  0.757082
# YFL032W  0.754269
# YDR150W  0.750867
# YDR149C  0.748252
# YDR334W  0.734474
# YJL154C  0.720486
# YHR079C  0.717771
# YDR485C  0.710932
# YNL041C  0.708964
# YNL051W  0.699161
#          Gene  R2 Score
# 83    YFL031W  0.757082
# 703   YFL032W  0.754269
# 661   YDR150W  0.750867
# 483   YDR149C  0.748252
# 2981  YDR334W  0.734474
# 3192  YJL154C  0.720486
# 2949  YHR079C  0.717771
# 1622  YDR485C  0.710932
# 3141  YNL041C  0.708964
# 2601  YNL051W  0.699161

# %% [markdown]
# ## ExN

# %%
results_ExN = iterate_over_proportion(ExE, proportion, predictive_model)
print_results(results_ExN)
plot_results(results_ExN)
print_top_genes(results_ExN, 'Ridge')
# Out:
# Model: Ridge
# Average R²:   0.4612
# Average RMSE: 0.0601
# Top 10 Genes by R² Score for Ridge:
#      Gene  R2 Score
#   YBL084C  0.810951
# YDR145W.2  0.805389
# YBL105C.1  0.790915
#   YHR188C  0.785961
# YJR076C.3  0.774518
#   YDR331W  0.771438
#   YLR314C  0.770758
# YCR002C.1  0.768029
#   YLR459W  0.763090
# YJR076C.4  0.762542
#           Gene  R2 Score
# 396    YBL084C  0.810951
# 223  YDR145W.2  0.805389
# 510  YBL105C.1  0.790915
# 173    YHR188C  0.785961
# 460  YJR076C.3  0.774518
# 425    YDR331W  0.771438
# 471    YLR314C  0.770758
# 195  YCR002C.1  0.768029
# 157    YLR459W  0.763090
# 606  YJR076C.4  0.762542

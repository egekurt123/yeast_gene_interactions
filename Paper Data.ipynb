# %%
import pandas as pd

# %%
df = pd.read_excel('data/Data File S5_SAFE analysis_Gene cluster identity and functional enrichments.xlsx', sheet_name='Global net. cluster gene list')

df
# Out:
#                   Global Similarity Network Region name        ORF Gene/Allele
# 0                         Cell polarity & morphogenesis    YLR378C     sec61-2
# 1                         Cell polarity & morphogenesis    YJR065C   arp3-d11a
# 2                         Cell polarity & morphogenesis    YNR035C     arc35-6
# 3                         Cell polarity & morphogenesis    YFL039C    act1-132
# 4                         Cell polarity & morphogenesis    YLL021W        spa2
# ...                                                 ...        ...         ...
# 1353  Respiration, oxidative phosphorylation, mitoch...    YGL235W     ygl235w
# 1354  Respiration, oxidative phosphorylation, mitoch...    YER077C     yer077c
# 1355  Respiration, oxidative phosphorylation, mitoch...    YKL107W     ykl107w
# 1356  Respiration, oxidative phosphorylation, mitoch...    YIL047C        syg1
# 1357  Respiration, oxidative phosphorylation, mitoch...  YJL133C-A   yjl133c-a
#
# [1358 rows x 3 columns]

# %%
ExE = pd.read_csv('extracted_data/ExE_imputed_5.csv', sep=',', index_col=0)
NxN = pd.read_csv('extracted_data/NxN_imputed_10.csv', sep=',', index_col=0)
ExN = pd.read_csv('extracted_data/ExN_filled_20.csv', sep=',', index_col=0)

# %%
ExE
# Out:
#          YDR478W  YHR040W  YIL104C   YDR064W  YDL208W  YMR290C   YLL011W  \
# gene_id
# YPR016C    0.065    0.013   -0.009  0.038000    0.068   -0.233 -0.015000
# YPR016C    0.096    0.070    0.010  0.083000    0.059   -0.245 -0.038000
# YBR109C    0.025   -0.005    0.062  0.020000    0.044   -0.172 -0.077000
# YBR109C    0.053    0.005    0.143  0.069000   -0.025   -0.379 -0.211000
# YDR280W   -0.074    0.032   -0.044 -0.020667    0.013    0.036 -0.073000
# ...          ...      ...      ...       ...      ...      ...       ...
# YAL038W    0.041    0.028    0.042  0.006000    0.034   -0.052  0.014000
# YBR055C    0.024   -0.046    0.049  0.006000   -0.004   -0.117 -0.053000
# YGR091W    0.058    0.067    0.019 -0.007000    0.029    0.021 -0.043000
# YLR105C    0.018    0.020    0.031  0.004000    0.007   -0.015 -0.010333
# YBR196C    0.023    0.001   -0.019  0.019000    0.006    0.004 -0.013000
#
#           YLR186W  YMR229C   YDR339C  ...  YBL034C.4  YBR055C.1   YLR105C  \
# gene_id                               ...
# YPR016C  0.059000    0.052  0.047000  ...  -0.028000  -0.049000  0.029000
# YPR016C  0.026000    0.108  0.079000  ...   0.029000  -0.014000  0.026000
# YBR109C  0.024000    0.107  0.128000  ...   0.018333   0.017000  0.040000
# YBR109C  0.057000   -0.127  0.076000  ...   0.004667  -0.035000  0.082000
# YDR280W -0.058000   -0.005 -0.072667  ...  -0.072000  -0.014000 -0.003000
# ...           ...      ...       ...  ...        ...        ...       ...
# YAL038W -0.007000    0.008 -0.016000  ...  -0.022000  -0.005000 -0.021000
# YBR055C  0.036000   -0.011 -0.018000  ...  -0.003667   0.008333 -0.003000
# YGR091W  0.065000    0.029  0.019000  ...  -0.043000  -0.011000  0.022000
# YLR105C  0.017333   -0.009  0.026000  ...  -0.069000  -0.007000  0.002333
# YBR196C  0.004000   -0.021 -0.079000  ...   0.010000   0.013000 -0.005000
#
#          YDL103C.1  YDL103C.2  YKL104C  YKL024C  YOR074C.1  YDR081C  YOR204W.2
# gene_id
# YPR016C      0.008      0.031    0.033   -0.093     -0.072   -0.003     -0.033
# YPR016C     -0.016      0.128   -0.036   -0.160      0.002   -0.024     -0.017
# YBR109C      0.044      0.045    0.107   -0.053      0.038    0.011     -0.010
# YBR109C      0.136      0.082    0.117   -0.257      0.082   -0.138      0.029
# YDR280W      0.029      0.025    0.008    0.041      0.104    0.031     -0.033
# ...            ...        ...      ...      ...        ...      ...        ...
# YAL038W      0.022     -0.004    0.017    0.027     -0.161    0.063     -0.028
# YBR055C      0.004      0.048    0.036    0.067      0.099    0.054      0.016
# YGR091W      0.014      0.020    0.023    0.060      0.055    0.113      0.043
# YLR105C      0.039      0.004    0.037    0.012      0.093    0.123      0.043
# YBR196C      0.014     -0.030   -0.006    0.042     -0.118    0.135      0.256
#
# [824 rows x 773 columns]

# %%
column_headers = ExE.columns.tolist()
gene_ids = ExE.index.tolist()

gene_ids
# Out:
# ['YPR016C',
#  'YPR016C',
#  'YBR109C',
#  'YBR109C',
#  'YDR280W',
#  'YHR069C',
#  'YGR158C',
#  'YNL232W',
#  'YDL111C',
#  'YGR195W',
#  'YOL021C',
#  'YJL050W',
#  'YOR294W',
#  'YKR081C',
#  'YLR196W',
#  'YLR340W',
#  'YLR022C',
#  'YNL163C',
#  'YNR053C',
#  'YHR170W',
#  'YLR397C',
#  'YEL055C',
#  'YMR049C',
#  'YLR002C',
#  'YHR040W',
#  'YDL014W',
#  'YEL026W',
#  'YLR197W',
#  'YOL144W',
#  'YDL031W',
#  'YNL002C',
#  'YLL008W',
#  'YDL031W',
#  'YLL008W',
#  'YHR088W',
#  'YKL082C',
#  'YOL077C',
#  'YNR038W',
#  'YBR142W',
#  'YLR276C',
#  'YHR088W',
#  'YPL043W',
#  'YDR087C',
#  'YPL211W',
#  'YNL061W',
#  'YNL061W',
#  'YNL061W',
#  'YGR103W',
#  'YDR060W',
#  'YNL061W',
#  'YHR197W',
#  'YHR085W',
#  'YER006W',
#  'YGR245C',
#  'YOR063W',
#  'YPR143W',
#  'YKL052C',
#  'YKR083C',
#  'YKL042W',
#  'YKR086W',
#  'YKL172W',
#  'YKR063C',
#  'YKL082C',
#  'YKR038C',
#  'YNL207W',
#  'YDL208W',
#  'YCL059C',
#  'YMR229C',
#  'YDR299W',
#  'YDR064W',
#  'YCL059C',
#  'YHR196W',
#  'YLL011W',
#  'YER082C',
#  'YER082C',
#  'YER127W',
#  'YER127W',
#  'YDR021W',
#  'YLR129W',
#  'YPL266W',
#  'YPR137W',
#  'YNL282W',
#  'YDR478W',
#  'YDR478W',
#  'YJL025W',
#  'YOR341W',
#  'YOR341W',
#  'YOR340C',
#  'YOR056C',
#  'YOR119C',
#  'YBR154C',
#  'YOL069W',
#  'YNL247W',
#  'YML125C',
#  'YMR290C',
#  'YMR211W',
#  'YBR236C',
#  'YMR227C',
#  'YAR019C',
#  'YGR092W',
#  'YGR092W',
#  'YGR092W',
#  'YNL126W',
#  'YGL001C',
#  'YGL207W',
#  'YOR204W',
#  'YLR163C',
#  'YAL041W',
#  'YKL021C',
#  'YDR361C',
#  'YEL055C',
#  'YBL105C',
#  'YHR019C',
#  'YBR153W',
#  'YIL104C',
#  'YBR265W',
#  'YAL041W',
#  'YKL125W',
#  'YGL055W',
#  'YGR099W',
#  'YHR007C',
#  'YDR172W',
#  'YHR107C',
#  'YBR160W',
#  'YFL034C-B',
#  'YER168C',
#  'YKL024C',
#  'YKL024C',
#  'YKL210W',
#  'YGR140W',
#  'YKL193C',
#  'YOR057W',
#  'YKR025W',
#  'YGR119C',
#  'YOR335C',
#  'YOL022C',
#  'YMR079W',
#  'YLR186W',
#  'YLR317W',
#  'YDR454C',
#  'YIL109C',
#  'YJR093C',
#  'YKL104C',
#  'YDL103C',
#  'YKL035W',
#  'YNL287W',
#  'YNL102W',
#  'YLR321C',
#  'YNL182C',
#  'YDR052C',
#  'YOR004W',
#  'YDR054C',
#  'YIL046W',
#  'YDL132W',
#  'YOL146W',
#  'YGR099W',
#  'YPL063W',
#  'YOL066C',
#  'YLL003W',
#  'YDR303C',
#  'YDR196C',
#  'YHR020W',
#  'YDR170C',
#  'YEL035C',
#  'YOL097C',
#  'YML043C',
#  'YNL112W',
#  'YDR339C',
#  'YJL005W',
#  'YDR050C',
#  'YHR083W',
#  'YNR017W',
#  'YOR232W',
#  'YMR298W',
#  'YGL155W',
#  'YFR031C',
#  'YDR182W',
#  'YHR068W',
#  'YDR324C',
#  'YJL033W',
#  'YGR198W',
#  'YLR409C',
#  'YNL181W',
#  'YPL083C',
#  'YDR211W',
#  'YGL111W',
#  'YGL099W',
#  'YLR259C',
#  'YNL112W',
#  'YNR054C',
#  'YPR180W',
#  'YPR169W',
#  'YDR190C',
#  'YDR365C',
#  'YDR324C',
#  'YHR062C',
#  'YOR063W',
#  'YJL054W',
#  'YPR035W',
#  'YDR376W',
#  'YIL019W',
#  'YDR301W',
#  'YIL091C',
#  'YJL061W',
#  'YNL112W',
#  'YDR037W',
#  'YPL117C',
#  'YDL031W',
#  'YDR232W',
#  'YJL010C',
#  'YJL069C',
#  'YLR424W',
#  'YLR141W',
#  'YPL231W',
#  'YDL153C',
#  'YMR301C',
#  'YLR409C',
#  'YDL031W',
#  'YDR232W',
#  'YGL169W',
#  'YNL221C',
#  'YLR355C',
#  'YJL069C',
#  'YLR141W',
#  'YLR424W',
#  'YNR054C',
#  'YPR035W',
#  'YPR048W',
#  'YPL117C',
#  'YDR037W',
#  'YPL231W',
#  'YPL243W',
#  'YPR180W',
#  'YLR440C',
#  'YLR440C',
#  'YOR075W',
#  'YGL098W',
#  'YLR212C',
#  'YLR153C',
#  'YML064C',
#  'YIR011C',
#  'YMR239C',
#  'YMR239C',
#  'YJL104W',
#  'YPL231W',
#  'YPL231W',
#  'YPL231W',
#  'YER125W',
#  'YER125W',
#  'YER125W',
#  'YBR143C',
#  'YPR103W',
#  'YBL041W',
#  'YGL011C',
#  'YFR050C',
#  'YER094C',
#  'YOL038W',
#  'YGR253C',
#  'YKL145W',
#  'YPR108W',
#  'YDL147W',
#  'YDL097C',
#  'YDL007W',
#  'YOR259C',
#  'YOR259C',
#  'YDL097C',
#  'YGL048C',
#  'YGL048C',
#  'YFR004W',
#  'YFR004W',
#  'YFR052W',
#  'YHR027C',
#  'YDR394W',
#  'YDL126C',
#  'YDL126C',
#  'YDL126C',
#  'YGR048W',
#  'YGL116W',
#  'YGL116W',
#  'YGL116W',
#  'YHR166C',
#  'YBL084C',
#  'YBL084C',
#  'YLR127C',
#  'YOR249C',
#  'YOR249C',
#  'YKL022C',
#  'YHR166C',
#  'YFR036W',
#  'YMR146C',
#  'YMR028W',
#  'YDL220C',
#  'YHR036W',
#  'YHR036W',
#  'YHR036W',
#  'YHR036W',
#  'YHR074W',
#  'YJL014W',
#  'YJL010C',
#  'YJL033W',
#  'YJL111W',
#  'YEL035C',
#  'YEL034W',
#  'YEL034W',
#  'YBR135W',
#  'YBR160W',
#  'YBR160W',
#  'YFL009W',
#  'YFL009W',
#  'YDR168W',
#  'YDR168W',
#  'YJR076C',
#  'YJR076C',
#  'YJR076C',
#  'YJR076C',
#  'YJR076C',
#  'YHR107C',
#  'YCR002C',
#  'YCR002C',
#  'YCR002C',
#  'YLR314C',
#  'YJL173C',
#  'YNL260C',
#  'YDL165W',
#  'YCR093W',
#  'YDL207W',
#  'YPR025C',
#  'YFL034C-B',
#  'YDR164C',
#  'YGR065C',
#  'YDR044W',
#  'YGR005C',
#  'YGR186W',
#  'YPL228W',
#  'YPL228W',
#  'YGL130W',
#  'YGL130W',
#  'YGL130W',
#  'YPR168W',
#  'YER022W',
#  'YOL135C',
#  'YHR058C',
#  'YHR058C',
#  'YBR193C',
#  'YOL135C',
#  'YOR174W',
#  'YMR112C',
#  'YKR062W',
#  'YOR143C',
#  'YDR364C',
#  'YDR088C',
#  'YDR088C',
#  'YGR006W',
#  'YGR006W',
#  'YFR037C',
#  'YCR052W',
#  'YML127W',
#  'YMR033W',
#  'YLR033W',
#  'YIL129C',
#  'YGR002C',
#  'YOR244W',
#  'YOR244W',
#  'YHR122W',
#  'YGL091C',
#  'YNL240C',
#  'YPR048W',
#  'YPR048W',
#  'YDL108W',
#  'YLR005W',
#  'YPR056W',
#  'YPL122C',
#  'YLR005W',
#  'YMR309C',
#  'YML015C',
#  'YML098W',
#  'YDR145W',
#  'YPL011C',
#  'YPL011C',
#  'YDR145W',
#  'YDR145W',
#  'YDR145W',
#  'YDR145W',
#  'YOR194C',
#  'YGR274C',
#  'YGR274C',
#  'YGL112C',
#  'YMR236W',
#  'YBR198C',
#  'YOR020C',
#  'YGR211W',
#  'YNL118C',
#  'YBR236C',
#  'YOL094C',
#  'YNL261W',
#  'YBL023C',
#  'YEL032W',
#  'YBR202W',
#  'YLR274W',
#  'YHR118C',
#  'YBR060C',
#  'YBR060C',
#  'YLL004W',
#  'YBR060C',
#  'YBR060C',
#  'YJL194W',
#  'YPR019W',
#  'YFR028C',
#  'YFR028C',
#  'YER148W',
#  'YBR136W',
#  'YBR087W',
#  'YJR006W',
#  'YDL102W',
#  'YDL102W',
#  'YDL102W',
#  'YKL045W',
#  'YNL102W',
#  'YNL102W',
#  'YNL102W',
#  'YNL102W',
#  'YNL102W',
#  'YFL009W',
#  'YBL035C',
#  'YDR082W',
#  'YDR489W',
#  'YGL113W',
#  'YLR103C',
#  'YNL262W',
#  'YDR013W',
#  'YDR052C',
#  'YDR052C',
#  'YDR052C',
#  'YDR052C',
#  'YDL017W',
#  'YDL017W',
#  'YHR164C',
#  'YDR113C',
#  'YJR057W',
#  'YJR057W',
#  'YFL039C',
#  'YIL143C',
#  'YIR012W',
#  'YIL026C',
#  'YIL003W',
#  'YIL003W',
#  'YIL003W',
#  'YIL091C',
#  'YOR095C',
#  'YIL142W',
#  'YIL142W',
#  'YPR105C',
#  'YIL147C',
#  'YMR220W',
#  'YHR186C',
#  'YDR141C',
#  'YPR133C',
#  'YPR161C',
#  'YPR161C',
#  'YML069W',
#  'YML069W',
#  'YDR527W',
#  'YOR262W',
#  'YDL140C',
#  'YMR061W',
#  'YLR115W',
#  'YOR250C',
#  'YGL044C',
#  'YDR228C',
#  'YDR228C',
#  'YML023C',
#  'YML023C',
#  'YML023C',
#  'YDL105W',
#  'YDL105W',
#  'YDL105W',
#  'YDL105W',
#  'YLR007W',
#  'YEL019C',
#  'YDR288W',
#  'YDR288W',
#  'YER038C',
#  'YPL020C',
#  'YDR510W',
#  'YLR383W',
#  'YPL085W',
#  'YNR026C',
#  'YLR208W',
#  'YFL034C-B',
#  'YGR172C',
#  'YGR172C',
#  'YAL043C',
#  'YGR156W',
#  'YGR156W',
#  'YNL222W',
#  'YDR498C',
#  'YER165W',
#  'YER165W',
#  'YER165W',
#  'YGL097W',
#  'YGL130W',
#  'YGL097W',
#  'YMR235C',
#  'YMR235C',
#  'YJL061W',
#  'YGL247W',
#  'YER009W',
#  'YER009W',
#  'YGR119C',
#  'YNL189W',
#  'YGL238W',
#  'YLR347C',
#  'YDR002W',
#  'YOR046C',
#  'YGL092W',
#  'YDL084W',
#  'YAL034W-A',
#  'YGR140W',
#  'YOL097C',
#  'YOR057W',
#  'YMR094W',
#  'YDR016C',
#  'YDR201W',
#  'YJR112W',
#  'YLR145W',
#  'YJR112W',
#  'YIR010W',
#  'YIR010W',
#  'YPL233W',
#  'YPL233W',
#  'YIL144W',
#  'YOL069W',
#  'YMR117C',
#  'YGL093W',
#  'YGL093W',
#  'YMR117C',
#  'YER018C',
#  'YGR179C',
#  'YBR211C',
#  'YGL061C',
#  'YGR113W',
#  'YGR113W',
#  'YFL037W',
#  'YPL209C',
#  'YBR156C',
#  'YDL028C',
#  'YDL028C',
#  'YBL034C',
#  'YGR113W',
#  'YFL008W',
#  'YER147C',
#  'YJL074C',
#  'YFL008W',
#  'YDL003W',
#  'YJL074C',
#  'YDR180W',
#  'YLR045C',
#  'YLR045C',
#  'YLR045C',
#  'YLR045C',
#  'YBL034C',
#  'YBL034C',
#  'YBL034C',
#  'YDL015C',
#  'YCR054C',
#  'YBL097W',
#  'YLR272C',
#  'YBL097W',
#  'YDR325W',
#  'YGL073W',
#  'YKL154W',
#  'YDR292C',
#  'YBR110W',
#  'YGL065C',
#  'YPL169C',
#  'YER172C',
#  'YER172C',
#  'YJL054W',
#  'YNL181W',
#  'YNL181W',
#  'YNL181W',
#  'YNL181W',
#  'YNL181W',
#  'YNL181W',
#  'YPL083C',
#  'YFL017C',
#  'YML092C',
#  'YDR196C',
#  'YGR277C',
#  'YDR531W',
#  'YDR182W',
#  'YDR182W',
#  'YDR182W',
#  'YER003C',
#  'YFL045C',
#  'YOR103C',
#  'YBR070C',
#  'YDL193W',
#  'YGL047W',
#  'YMR013C',
#  'YHR190W',
#  'YLR314C',
#  'YHR072W',
#  'YHR072W',
#  'YHR072W',
#  'YML126C',
#  'YPL028W',
#  'YNR043W',
#  'YBR029C',
#  'YIL048W',
#  'YGL022W',
#  'YMR200W',
#  'YHR101C',
#  'YOR336W',
#  'YJL034W',
#  'YEL002C',
#  'YEL002C',
#  'YIR006C',
#  'YNL158W',
#  'YLL031C',
#  'YLL031C',
#  'YDR434W',
#  'YLR459W',
#  'YHR188C',
#  'YLR459W',
#  'YLR459W',
#  'YDR331W',
#  'YNL038W',
#  'YGL142C',
#  'YDR437W',
#  'YDR437W',
#  'YPL076W',
#  'YPL076W',
#  'YJL091C',
#  'YBR011C',
#  'YBL105C',
#  'YBL105C',
#  'YBL105C',
#  'YBL105C',
#  'YGL022W',
#  'YLR378C',
#  'YDR086C',
#  'YPL094C',
#  'YOR254C',
#  'YML130C',
#  'YLR066W',
#  'YMR149W',
#  'YMR149W',
#  'YJL002C',
#  'YLR430W',
#  'YER157W',
#  'YER157W',
#  'YIL004C',
#  'YKL196C',
#  'YLR078C',
#  'YLR268W',
#  'YMR197C',
#  'YMR197C',
#  'YGR120C',
#  'YKR068C',
#  'YML077W',
#  'YDR246W',
#  'YBR254C',
#  'YDL058W',
#  'YFL038C',
#  'YPL010W',
#  'YDR189W',
#  'YFR051C',
#  'YGL137W',
#  'YDR238C',
#  'YBL050W',
#  'YBR080C',
#  'YDL145C',
#  'YDR238C',
#  'YNL267W',
#  'YNL267W',
#  'YDR373W',
#  'YLR195C',
#  'YGR060W',
#  'YMR218C',
#  'YAL041W',
#  'YAL041W',
#  'YAL041W',
#  'YAL041W',
#  'YLR229C',
#  'YNL138W',
#  'YBR109C',
#  'YOR122C',
#  'YOR326W',
#  'YOR326W',
#  'YPR176C',
#  'YOR370C',
#  'YJL085W',
#  'YIL068C',
#  'YER136W',
#  'YNL272C',
#  'YJL085W',
#  'YBR102C',
#  'YGL233W',
#  'YPR055W',
#  'YER008C',
#  'YLR166C',
#  'YDR166C',
#  'YIL118W',
#  'YGR009C',
#  'YDR208W',
#  'YBR234C',
#  'YDL029W',
#  'YFL039C',
#  'YFL039C',
#  'YFL039C',
#  'YFL039C',
#  'YFL039C',
#  'YFL039C',
#  'YFL039C',
#  'YFL039C',
#  'YFL039C',
#  'YFL039C',
#  'YFL039C',
#  'YFL039C',
#  'YFL039C',
#  'YFL039C',
#  'YOR181W',
#  'YOR181W',
#  'YIL062C',
#  'YNR035C',
#  'YOR281C',
#  'YDR212W',
#  'YDL143W',
#  'YLR305C',
#  'YMR296C',
#  'YMR296C',
#  'YMR296C',
#  'YNL006W',
#  'YKL203C',
#  'YKL203C',
#  'YER093C',
#  'YER093C',
#  'YER093C',
#  'YNL006W',
#  'YPR033C',
#  'YBL076C',
#  'YPL231W',
#  'YDL103C',
#  'YDL103C',
#  'YPL209C',
#  'YJL035C',
#  'YLR215C',
#  'YOR260W',
#  'YLR291C',
#  'YOR260W',
#  'YGR185C',
#  'YPL160W',
#  'YDR341C',
#  'YNL062C',
#  'YBR167C',
#  'YDL150W',
#  'YDR045C',
#  'YOR116C',
#  'YNL151C',
#  'YPL007C',
#  'YHR062C',
#  'YNR003C',
#  'YBR123C',
#  'YOR168W',
#  'YAL001C',
#  'YBR079C',
#  'YMR309C',
#  'YMR309C',
#  'YMR309C',
#  'YPL122C',
#  'YOR361C',
#  'YBR079C',
#  'YOR204W',
#  'YOR204W',
#  'YLR316C',
#  'YDL060W',
#  'YLR259C',
#  'YLR323C',
#  'YLR323C',
#  'YLR323C',
#  'YGR013W',
#  'YDR235W',
#  'YML046W',
#  'YDL087C',
#  'YLR298C',
#  'YLR116W',
#  'YLR298C',
#  'YLR116W',
#  'YDL043C',
#  'YPR094W',
#  'YML049C',
#  'YBR237W',
#  'YJL203W',
#  'YMR240C',
#  'YLR298C',
#  'YBL074C',
#  'YPL151C',
#  'YGL120C',
#  'YNR011C',
#  'YGR278W',
#  'YER013W',
#  'YMR213W',
#  'YKR086W',
#  'YKL173W',
#  'YBR055C',
#  'YBR152W',
#  'YDL098C',
#  'YGR075C',
#  'YBL026W',
#  'YMR268C',
#  'YPR178W',
#  'YGR091W',
#  'YDR473C',
#  'YDR243C',
#  'YKL173W',
#  'YPR178W',
#  'YLL050C',
#  'YLL050C',
#  'YAL038W',
#  'YBR055C',
#  'YGR091W',
#  'YLR105C',
#  'YBR196C']

# %%
common_elements = set(column_headers) & set(gene_ids)
len(common_elements)
# Out:
# 420

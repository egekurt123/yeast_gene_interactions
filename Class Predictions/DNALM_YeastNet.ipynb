# %%
from class_prediction_helpers import *

# %%
embeddings = pd.read_csv('../extracted_data/yeast_emb_embeddings_yeastnet.csv', sep=',', index_col=0)
embeddings = embeddings.set_index('gene_id')
embeddings
# Out:
#            gc_5_prime  gc_3_prime    gc_cds       AAA       AAC       AAG  \
# gene_id
# YAL002W      0.365902    0.310000  0.372057  0.043956  0.019623  0.018053
# YAL003W      0.372881    0.253333  0.448220  0.009709  0.024272  0.077670
# YAL004W      0.417747    0.346667  0.451163  0.023256  0.023256  0.000000
# YAL008W      0.381854    0.296667  0.388889  0.045455  0.020202  0.040404
# YAL009W      0.368893    0.323333  0.414414  0.042471  0.011583  0.023166
# ...               ...         ...       ...       ...       ...       ...
# YPR195C      0.334995    0.393333  0.467890  0.027523  0.000000  0.000000
# YPR197C      0.376869    0.276667  0.374332  0.058824  0.021390  0.021390
# YPR199C      0.329013    0.283333  0.391156  0.030612  0.020408  0.047619
# YPR200C      0.366899    0.313333  0.376923  0.038462  0.015385  0.038462
# YPR204C-A    0.402189    0.426667  0.454167  0.031250  0.018750  0.000000
#
#                 AAT       ACA       ACC       ACG  ...  yeastnet_118  \
# gene_id                                            ...
# YAL002W    0.039246  0.013344  0.007849  0.011774  ...      0.478499
# YAL003W    0.004854  0.000000  0.019417  0.000000  ...     -0.098657
# YAL004W    0.046512  0.004651  0.074419  0.013953  ...      0.304043
# YAL008W    0.050505  0.015152  0.005051  0.010101  ...     -1.473497
# YAL009W    0.027027  0.011583  0.007722  0.007722  ...     -0.163302
# ...             ...       ...       ...       ...  ...           ...
# YPR195C    0.027523  0.045872  0.009174  0.036697  ...      0.304043
# YPR197C    0.016043  0.042781  0.005348  0.005348  ...      0.304043
# YPR199C    0.047619  0.027211  0.003401  0.013605  ...      0.354289
# YPR200C    0.023077  0.030769  0.015385  0.007692  ...     -0.277727
# YPR204C-A  0.012500  0.000000  0.006250  0.018750  ...      0.304043
#
#            yeastnet_119  yeastnet_120  yeastnet_121  yeastnet_122  \
# gene_id
# YAL002W       -0.583731      0.274917     -0.038427      0.364670
# YAL003W       -1.633584      1.431733      0.139956     -0.149676
# YAL004W       -0.692107      0.406243     -0.507120     -0.471877
# YAL008W       -0.517920      0.636498     -1.859366     -0.178091
# YAL009W       -0.198140      0.473834     -1.629398     -0.357276
# ...                 ...           ...           ...           ...
# YPR195C       -0.692107      0.406243     -0.507120     -0.471877
# YPR197C       -0.692107      0.406243     -0.507120     -0.471877
# YPR199C       -0.667019     -0.359680     -0.440918     -0.685408
# YPR200C       -1.299612     -0.803733      0.208995     -1.460642
# YPR204C-A     -0.692107      0.406243     -0.507120     -0.471877
#
#            yeastnet_123  yeastnet_124  yeastnet_125  yeastnet_126  \
# gene_id
# YAL002W        0.971628     -1.505513      0.762765      0.048427
# YAL003W        0.679022     -0.111370     -0.890566     -2.230226
# YAL004W        0.454804     -0.539081     -0.150458      0.084854
# YAL008W       -0.368822     -1.928968      0.472724     -0.114895
# YAL009W        0.543951     -0.673144     -0.122125     -0.238568
# ...                 ...           ...           ...           ...
# YPR195C        0.454804     -0.539081     -0.150458      0.084854
# YPR197C        0.454804     -0.539081     -0.150458      0.084854
# YPR199C        0.428187     -0.988392      1.157113      0.325579
# YPR200C        0.672835      0.406970      0.275635      0.664265
# YPR204C-A      0.454804     -0.539081     -0.150458      0.084854
#
#            yeastnet_127
# gene_id
# YAL002W       -0.517894
# YAL003W        2.147701
# YAL004W        0.829506
# YAL008W       -0.265905
# YAL009W        1.432465
# ...                 ...
# YPR195C        0.829506
# YPR197C        0.829506
# YPR199C       -0.009973
# YPR200C        0.997513
# YPR204C-A      0.829506
#
# [6579 rows x 3011 columns]

# %%
get_class_predictions(embeddings)
# Out:
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# === RandomForestClassifier() ===
# Accuracy: 0.8610567514677103
# Precision: 0.6666666666666666
# Recall: 0.013986013986013986
# F1 score: 0.0273972602739726
# Info: Ratio of non-essential genes in the dataset: 0.8614492753623189
#
#
# Essential classified genes:
#   Precision: 0.667
#   Recall: 0.014
#
# Nonessential classified genes:
#   Precision: 0.862
#   Recall: 0.999
#
# === LogisticRegression(max_iter=500) ===
# Accuracy: 0.8571428571428571
# Precision: 0.48739495798319327
# Recall: 0.40559440559440557
# F1 score: 0.44274809160305345
# Info: Ratio of non-essential genes in the dataset: 0.8614492753623189
#
#
# Essential classified genes:
#   Precision: 0.487
#   Recall: 0.406
#
# Nonessential classified genes:
#   Precision: 0.906
#   Recall: 0.931

# %%
get_class_predictions_balanced(embeddings)
# Out:
# === RandomForestClassifier() ===
# Accuracy: 0.9840637450199203
# Precision: 0.9775280898876404
# Recall: 0.9908883826879271
# F1 score: 0.9841628959276018
# Info: Ratio of non-essential genes in the balanced dataset: 0.5
#
#
# Essential classified genes:
#   Precision: 0.978
#   Recall: 0.991
#
# Nonessential classified genes:
#   Precision: 0.991
#   Recall: 0.977
#
# === LogisticRegression(max_iter=500) ===
# Accuracy: 0.9254410927717701
# Precision: 0.8870466321243523
# Recall: 0.9749430523917996
# F1 score: 0.9289202387411829
# Info: Ratio of non-essential genes in the balanced dataset: 0.5
#
#
# Essential classified genes:
#   Precision: 0.887
#   Recall: 0.975
#
# Nonessential classified genes:
#   Precision: 0.972
#   Recall: 0.876
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(

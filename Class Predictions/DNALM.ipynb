# %%
from class_prediction_helpers import *

# %%
embeddings = pd.read_csv('../extracted_data/yeast_emb_only_embeddings.csv', sep=',', index_col=0)
embeddings = embeddings.set_index('gene_id')
embeddings
# Out:
#            gc_5_prime  gc_3_prime    gc_cds       AAA       AAC       AAG  \
# gene_id
# YAL002W      0.365902    0.310000  0.372057  0.043956  0.019623  0.018053
# YAL003W      0.372881    0.253333  0.448220  0.009709  0.024272  0.077670
# YAL004W      0.417747    0.346667  0.451163  0.023256  0.023256  0.000000
# YAL008W      0.381854    0.296667  0.388889  0.045455  0.020202  0.040404
# YAL009W      0.368893    0.323333  0.414414  0.042471  0.011583  0.023166
# ...               ...         ...       ...       ...       ...       ...
# YPR195C      0.334995    0.393333  0.467890  0.027523  0.000000  0.000000
# YPR197C      0.376869    0.276667  0.374332  0.058824  0.021390  0.021390
# YPR199C      0.329013    0.283333  0.391156  0.030612  0.020408  0.047619
# YPR200C      0.366899    0.313333  0.376923  0.038462  0.015385  0.038462
# YPR204C-A    0.402189    0.426667  0.454167  0.031250  0.018750  0.000000
#
#                 AAT       ACA       ACC       ACG  ...  LM_5UTR_758  \
# gene_id                                            ...
# YAL002W    0.039246  0.013344  0.007849  0.011774  ...    -0.078495
# YAL003W    0.004854  0.000000  0.019417  0.000000  ...    -0.036358
# YAL004W    0.046512  0.004651  0.074419  0.013953  ...    -0.075972
# YAL008W    0.050505  0.015152  0.005051  0.010101  ...     0.041582
# YAL009W    0.027027  0.011583  0.007722  0.007722  ...    -0.040703
# ...             ...       ...       ...       ...  ...          ...
# YPR195C    0.027523  0.045872  0.009174  0.036697  ...    -0.069516
# YPR197C    0.016043  0.042781  0.005348  0.005348  ...    -0.014195
# YPR199C    0.047619  0.027211  0.003401  0.013605  ...     0.052901
# YPR200C    0.023077  0.030769  0.015385  0.007692  ...     0.087128
# YPR204C-A  0.012500  0.000000  0.006250  0.018750  ...    -0.156648
#
#            LM_5UTR_759  LM_5UTR_760  LM_5UTR_761  LM_5UTR_762  LM_5UTR_763  \
# gene_id
# YAL002W      -0.101951    -0.451596     0.140201    -0.027987    -0.139936
# YAL003W      -0.086898    -0.285149     0.175611     0.077306    -0.061331
# YAL004W      -0.245783    -0.237227     0.035347     0.030442    -0.027595
# YAL008W      -0.064832    -0.376715     0.091384     0.042122    -0.061658
# YAL009W      -0.020197    -0.345180     0.086169     0.088264    -0.025787
# ...                ...          ...          ...          ...          ...
# YPR195C      -0.091421    -0.402476     0.095457     0.023955    -0.072979
# YPR197C      -0.102008    -0.424302     0.133435     0.087042    -0.024667
# YPR199C      -0.037409    -0.385326     0.083647     0.060815    -0.034371
# YPR200C      -0.082817    -0.418286     0.099563     0.080339    -0.000032
# YPR204C-A     0.045181    -0.139266    -0.008859    -0.057025    -0.011356
#
#            LM_5UTR_764  LM_5UTR_765  LM_5UTR_766  LM_5UTR_767
# gene_id
# YAL002W       0.119334    -0.009675     0.035513    -0.042870
# YAL003W       0.043992     0.006744    -0.069993    -0.174272
# YAL004W       0.166694     0.106680     0.595686     0.108673
# YAL008W       0.052838     0.059197    -0.438873    -0.127666
# YAL009W       0.143896    -0.037077    -0.682068    -0.134648
# ...                ...          ...          ...          ...
# YPR195C      -0.082304     0.072628    -0.665834     0.037950
# YPR197C       0.205772     0.009731    -0.687237     0.048592
# YPR199C       0.054171     0.069161    -0.484573    -0.094109
# YPR200C       0.105696     0.047736    -0.490977     0.055293
# YPR204C-A    -0.102257     0.084706     0.247004    -0.005747
#
# [6579 rows x 2883 columns]

# %%
get_class_predictions(embeddings)
# Out:
# === RandomForestClassifier() ===
# Accuracy: 0.863013698630137
# Precision: 0.8
# Recall: 0.027972027972027972
# F1 score: 0.05405405405405406
# Info: Ratio of non-essential genes in the dataset: 0.8614492753623189
#
#
# Essential classified genes:
#   Precision: 0.800
#   Recall: 0.028
#
# Nonessential classified genes:
#   Precision: 0.863
#   Recall: 0.999
#
# === LogisticRegression(max_iter=500) ===
# Accuracy: 0.860078277886497
# Precision: 0.5
# Recall: 0.3776223776223776
# F1 score: 0.4302788844621514
# Info: Ratio of non-essential genes in the dataset: 0.8614492753623189
#
#
# Essential classified genes:
#   Precision: 0.500
#   Recall: 0.378
#
# Nonessential classified genes:
#   Precision: 0.903
#   Recall: 0.939
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(

# %%
get_class_predictions_balanced(embeddings)
# Out:
# === RandomForestClassifier() ===
# Accuracy: 0.9846328969834945
# Precision: 0.9786276715410573
# Recall: 0.9908883826879271
# F1 score: 0.9847198641765704
# Info: Ratio of non-essential genes in the balanced dataset: 0.5
#
#
# Essential classified genes:
#   Precision: 0.979
#   Recall: 0.991
#
# Nonessential classified genes:
#   Precision: 0.991
#   Recall: 0.978
#
# === LogisticRegression(max_iter=500) ===
# Accuracy: 0.9214570290267502
# Precision: 0.8838174273858921
# Recall: 0.9703872437357631
# F1 score: 0.9250814332247557
# Info: Ratio of non-essential genes in the balanced dataset: 0.5
#
#
# Essential classified genes:
#   Precision: 0.884
#   Recall: 0.970
#
# Nonessential classified genes:
#   Precision: 0.967
#   Recall: 0.873
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(

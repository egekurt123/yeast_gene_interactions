# %%
from class_prediction_helpers import *

# %%
embeddings = pd.read_csv('../extracted_data/yeast_emb_embeddings_yeastnet_orthogroup.csv', sep=',', index_col=0)
embeddings = embeddings.set_index('gene_id')
embeddings
# Out:
#            gc_5_prime  gc_3_prime    gc_cds       AAA       AAC       AAG  \
# gene_id
# YAL002W      0.365902    0.310000  0.372057  0.043956  0.019623  0.018053
# YAL003W      0.372881    0.253333  0.448220  0.009709  0.024272  0.077670
# YAL004W      0.417747    0.346667  0.451163  0.023256  0.023256  0.000000
# YAL008W      0.381854    0.296667  0.388889  0.045455  0.020202  0.040404
# YAL009W      0.368893    0.323333  0.414414  0.042471  0.011583  0.023166
# ...               ...         ...       ...       ...       ...       ...
# YPR195C      0.334995    0.393333  0.467890  0.027523  0.000000  0.000000
# YPR197C      0.376869    0.276667  0.374332  0.058824  0.021390  0.021390
# YPR199C      0.329013    0.283333  0.391156  0.030612  0.020408  0.047619
# YPR200C      0.366899    0.313333  0.376923  0.038462  0.015385  0.038462
# YPR204C-A    0.402189    0.426667  0.454167  0.031250  0.018750  0.000000
#
# ...

# %%
get_class_predictions(embeddings)
# Out:
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# === RandomForestClassifier() ===
# Accuracy: 0.8638132295719845
# Precision: 1.0
# Recall: 0.027777777777777776
# F1 score: 0.05405405405405406
# Info: Ratio of non-essential genes in the dataset: 0.8614492753623189
#
#
# Essential classified genes:
#   Precision: 1.000
#   Recall: 0.028
#
# Nonessential classified genes:
#   Precision: 0.863
#   Recall: 1.000
#
# === LogisticRegression(max_iter=500) ===
# ...

# %%
get_class_predictions_balanced(embeddings)
# Out:
# === RandomForestClassifier() ===
# Accuracy: 0.8735408560311284
# Precision: 0.7333333333333333
# Recall: 0.1527777777777778
# F1 score: 0.25287356321839083
# Info: Ratio of non-essential genes in the balanced dataset: 0.5
#
#
# Essential classified genes:
#   Precision: 0.733
#   Recall: 0.153
#
# Nonessential classified genes:
#   Precision: 0.878
#   Recall: 0.991
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# === LogisticRegression(max_iter=500) ===
# ...

# %%
get_class_predictions_bootstrapped(embeddings)
# Out:
# === RandomForestClassifier(random_state=42) with Bootstrapping ===
# Accuracy: 0.8375486381322957
# Precision: 0.4444444444444444
# Recall: 0.6388888888888888
# F1 score: 0.5242165242165242
#
#
# Essential classified genes:
#   Precision: 0.444
#   Recall: 0.639
#
# Nonessential classified genes:
#   Precision: 0.937
#   Recall: 0.870
#
# === LogisticRegression(max_iter=500, random_state=42) with Bootstrapping ===
# Accuracy: 0.7976653696498055
# Precision: 0.3805970149253731
# Recall: 0.7083333333333334
# F1 score: 0.49514563106796117
#
#
# Essential classified genes:
#   Precision: 0.381
#   Recall: 0.708
#
# Nonessential classified genes:
#   Precision: 0.945
#   Recall: 0.812

# %%
from class_prediction_helpers import *

# %%
dnalm = pd.read_csv('../extracted_data/yeast_emb_only_embeddings.csv', sep=',', index_col=0)
dnalm = dnalm.set_index('gene_id')

dnalm_yeastnet = pd.read_csv('../extracted_data/yeast_emb_embeddings_yeastnet.csv', sep=',', index_col=0)
dnalm_yeastnet = dnalm_yeastnet.set_index('gene_id')

dnalm_genex = pd.read_csv('../extracted_data/yeast_emb_embeddings_genex.csv', sep=',', index_col=0)
dnalm_genex = dnalm_genex.set_index('gene_id')

dnalm_orthogroups = pd.read_csv('../extracted_data/yeast_emb_embeddings_orthogroup.csv', sep=',', index_col=0)
dnalm_orthogroups = dnalm_orthogroups.set_index('gene_id')

dnalm_yeastnet_genex = pd.read_csv('../extracted_data/yeast_emb_embeddings_yeastnet_genex.csv', sep=',', index_col=0)
dnalm_yeastnet_genex = dnalm_yeastnet_genex.set_index('gene_id')

dnalm_yeastnet_orthogroups = pd.read_csv('../extracted_data/yeast_emb_embeddings_yeastnet_orthogroup.csv', sep=',', index_col=0)  
dnalm_yeastnet_orthogroups = dnalm_yeastnet_orthogroups.set_index('gene_id')  

dnalm_orthogroups_genex = pd.read_csv('../extracted_data/yeast_emb_embeddings_genex_orthogroup.csv', sep=',', index_col=0)
dnalm_orthogroups_genex = dnalm_orthogroups_genex.set_index('gene_id')

full = pd.read_csv('../extracted_data/yeast_emb_full.csv', sep=',', index_col=0)
full = full.set_index('gene_id')

# %%
compare_prec_recalls("Logistic_Regression",(dnalm, "DNALM"), (dnalm_yeastnet, "DNALM + YeastNet"), 
                    (dnalm_genex, "DNALM + Gene Expressions"), (dnalm_orthogroups, 'DNALM + Orthologous Groups'),
                    (dnalm_yeastnet_genex, "DNALM + Yeastnet + Gene Expressions"),
                    (dnalm_yeastnet_orthogroups, "DNALM + Yeastnet + Orthologous Groups"),
                    (dnalm_orthogroups_genex, "DNALM + Orthologous Groups + Gene Expressions"),
                    (full, "Full Model"))
# Out:
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# ...

# %%
compare_prec_recalls("Random_Forests_Classifier",(dnalm, "DNALM"), (dnalm_yeastnet, "DNALM + YeastNet"), 
                    (dnalm_genex, "DNALM + Gene Expressions"), (dnalm_orthogroups, 'DNALM + Orthologous Groups'),
                    (dnalm_yeastnet_genex, "DNALM + Yeastnet + Gene Expressions"),
                    (dnalm_yeastnet_orthogroups, "DNALM + Yeastnet + Orthologous Groups"),
                    (dnalm_orthogroups_genex, "DNALM + Orthologous Groups + Gene Expressions"),
                    (full, "Full Model"))

# %% [markdown]
# ## Balanced

# %%
compare_prec_recalls_balanced("Logistic_Regression",(dnalm, "DNALM"), (dnalm_yeastnet, "DNALM + YeastNet"), 
                    (dnalm_genex, "DNALM + Gene Expressions"), (dnalm_orthogroups, 'DNALM + Orthologous Groups'),
                    (dnalm_yeastnet_genex, "DNALM + Yeastnet + Gene Expressions"),
                    (dnalm_yeastnet_orthogroups, "DNALM + Yeastnet + Orthologous Groups"),
                    (dnalm_orthogroups_genex, "DNALM + Orthologous Groups + Gene Expressions"),
                    (full, "Full Model"))
# Out:
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# ...

# %%
compare_prec_recalls_balanced("Random_Forests_Classifier",(dnalm, "DNALM"), (dnalm_yeastnet, "DNALM + YeastNet"), 
                    (dnalm_genex, "DNALM + Gene Expressions"), (dnalm_orthogroups, 'DNALM + Orthologous Groups'),
                    (dnalm_yeastnet_genex, "DNALM + Yeastnet + Gene Expressions"),
                    (dnalm_yeastnet_orthogroups, "DNALM + Yeastnet + Orthologous Groups"),
                    (dnalm_orthogroups_genex, "DNALM + Orthologous Groups + Gene Expressions"),
                    (full, "Full Model"))

# %% [markdown]
# ## Bootstrapped

# %%
compare_prec_recalls_bootstrapped("Logistic_Regression", 5, (dnalm, "DNALM"), (dnalm_yeastnet, "DNALM + YeastNet"), 
                    (dnalm_genex, "DNALM + Gene Expressions"), (dnalm_orthogroups, 'DNALM + Orthologous Groups'),
                    (dnalm_yeastnet_genex, "DNALM + Yeastnet + Gene Expressions"),
                    (dnalm_yeastnet_orthogroups, "DNALM + Yeastnet + Orthologous Groups"),
                    (dnalm_orthogroups_genex, "DNALM + Orthologous Groups + Gene Expressions"),
                    (full, "Full Model"))
# Out:
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# ...

# %%
compare_prec_recalls_bootstrapped("Random_Forests_Classifier", 5, (dnalm, "DNALM"), (dnalm_yeastnet, "DNALM + YeastNet"), 
                    (dnalm_genex, "DNALM + Gene Expressions"), (dnalm_orthogroups, 'DNALM + Orthologous Groups'),
                    (dnalm_yeastnet_genex, "DNALM + Yeastnet + Gene Expressions"),
                    (dnalm_yeastnet_orthogroups, "DNALM + Yeastnet + Orthologous Groups"),
                    (dnalm_orthogroups_genex, "DNALM + Orthologous Groups + Gene Expressions"),
                    (full, "Full Model"))

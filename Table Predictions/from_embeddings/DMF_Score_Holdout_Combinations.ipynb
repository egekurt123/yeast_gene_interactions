# %%
from embedding_prediction_helpers import *

# %%
DNALM = pd.read_csv('../../extracted_data/yeast_emb_only_embeddings.csv', sep=',', index_col=0).set_index("gene_id")
DNALM_Genex = pd.read_csv('../../extracted_data/yeast_emb_embeddings_genex.csv', sep=',', index_col=0).set_index("gene_id")
DNALM_YeastNet = pd.read_csv('../../extracted_data/yeast_emb_embeddings_yeastnet.csv', sep=',', index_col=0).set_index("gene_id")
DNALM_YeastNet_Genex = pd.read_csv('../../extracted_data/yeast_emb_embeddings_yeastnet_genex.csv', sep=',', index_col=0).set_index("gene_id")

# %%
r2_dnalm = predict_all_models_holdout(DNALM, "DNALM", prediction_type="dmf")
# Out:
# Running for combination: DNALM
#
#
# Randomly selected 537 holdout genes to cover ~20% of data.
# Linear Regression
# R2: -10.443
# RMSE: 0.855
#
#
# Randomly selected 537 holdout genes to cover ~20% of data.
# Ridge Regression
# R2: 0.153
# RMSE: 0.233
#
#
# Randomly selected 537 holdout genes to cover ~20% of data.
# XGBoost Regression
# R2: 0.228
# RMSE: 0.222
#
#
# Randomly selected 537 holdout genes to cover ~20% of data.
# Random Forest Regression
# R2: 0.171
# RMSE: 0.230

# %%
r2_dnalm_yeastnet = predict_all_models_holdout(DNALM_YeastNet, "DNALM + YeastNet", prediction_type="dmf")
# Out:
# Running for combination: DNALM + YeastNet
#
#
# Randomly selected 537 holdout genes to cover ~20% of data.
# Linear Regression
# R2: -30.149
# RMSE: 1.410
#
#
# Randomly selected 537 holdout genes to cover ~20% of data.
# Ridge Regression
# R2: 0.177
# RMSE: 0.229
#
#
# Randomly selected 537 holdout genes to cover ~20% of data.
# XGBoost Regression
# R2: 0.222
# RMSE: 0.223
#
#
# Randomly selected 537 holdout genes to cover ~20% of data.
# Random Forest Regression
# R2: 0.173
# RMSE: 0.230

# %%
r2_dnalm_genex = predict_all_models_holdout(DNALM_Genex, "DNALM + Gene Expressions", prediction_type="dmf")
# Out:
# Running for combination: DNALM + Gene Expressions
#
#
# Randomly selected 537 holdout genes to cover ~20% of data.
# Linear Regression
# R2: -9.331
# RMSE: 0.812
#
#
# Randomly selected 537 holdout genes to cover ~20% of data.
# Ridge Regression
# R2: 0.235
# RMSE: 0.221
#
#
# Randomly selected 537 holdout genes to cover ~20% of data.
# XGBoost Regression
# R2: 0.375
# RMSE: 0.200
#
#
# Randomly selected 537 holdout genes to cover ~20% of data.
# Random Forest Regression
# R2: 0.327
# RMSE: 0.207

# %%
r2_dnalm_yeastnet_genex = predict_all_models_holdout(DNALM_YeastNet_Genex, "DNALM + YeastNet + Gene Expressions", prediction_type="dmf")
# Out:
# Running for combination: DNALM + YeastNet + Gene Expressions
#
#
# Randomly selected 537 holdout genes to cover ~20% of data.
# Linear Regression
# R2: -36.814
# RMSE: 1.554
#
#
# Randomly selected 537 holdout genes to cover ~20% of data.
# Ridge Regression
# R2: 0.249
# RMSE: 0.219
#
#
# Randomly selected 537 holdout genes to cover ~20% of data.
# XGBoost Regression
# R2: 0.378
# RMSE: 0.199
#
#
# Randomly selected 537 holdout genes to cover ~20% of data.
# Random Forest Regression
# R2: 0.326
# RMSE: 0.207

# %%
plot_r2_combinations(r2_dnalm, r2_dnalm_yeastnet, r2_dnalm_genex, r2_dnalm_yeastnet_genex)

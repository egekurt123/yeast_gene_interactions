# %%
import sys
import os
sys.path.append(os.path.abspath(".."))

# %%
from embedding_prediction_helpers import *

# %%
embeddings = pd.read_csv('../../../extracted_data/yeast_emb_embeddings_yeastnet_genex.csv', sep=',', index_col=0)
embeddings = embeddings.set_index('gene_id')
embeddings
# Out:
#            gc_5_prime  gc_3_prime    gc_cds       AAA       AAC       AAG  \
# gene_id
# YAL002W      0.365902    0.310000  0.372057  0.043956  0.019623  0.018053
# YAL003W      0.372881    0.253333  0.448220  0.009709  0.024272  0.077670
# YAL004W      0.417747    0.346667  0.451163  0.023256  0.023256  0.000000
# YAL008W      0.381854    0.296667  0.388889  0.045455  0.020202  0.040404
# YAL009W      0.368893    0.323333  0.414414  0.042471  0.011583  0.023166
# ...               ...         ...       ...       ...       ...       ...
# YPR195C      0.334995    0.393333  0.467890  0.027523  0.000000  0.000000
# YPR197C      0.376869    0.276667  0.374332  0.058824  0.021390  0.021390
# YPR199C      0.329013    0.283333  0.391156  0.030612  0.020408  0.047619
# YPR200C      0.366899    0.313333  0.376923  0.038462  0.015385  0.038462
# YPR204C-A    0.402189    0.426667  0.454167  0.031250  0.018750  0.000000
#
#                 AAT       ACA       ACC       ACG  ...  \
# gene_id                                            ...
# YAL002W    0.039246  0.013344  0.007849  0.011774  ...
# YAL003W    0.004854  0.000000  0.019417  0.000000  ...
# YAL004W    0.046512  0.004651  0.074419  0.013953  ...
# YAL008W    0.050505  0.015152  0.005051  0.010101  ...
# YAL009W    0.027027  0.011583  0.007722  0.007722  ...
# ...             ...       ...       ...       ...  ...
# YPR195C    0.027523  0.045872  0.009174  0.036697  ...
# YPR197C    0.016043  0.042781  0.005348  0.005348  ...
# YPR199C    0.047619  0.027211  0.003401  0.013605  ...
# YPR200C    0.023077  0.030769  0.015385  0.007692  ...
# YPR204C-A  0.012500  0.000000  0.006250  0.018750  ...
#
#            data_Turco_expression_11808  data_Turco_expression_16247  \
# gene_id
# YAL002W                      -1.454995                     0.120081
# YAL003W                       0.187259                    -0.020342
# YAL004W                       0.187259                    -0.020342
# YAL008W                       0.200656                     0.120081
# YAL009W                       0.203895                     0.120081
# ...                                ...                          ...
# YPR195C                       0.187259                    -0.020342
# YPR197C                       0.187259                    -0.020342
# YPR199C                      -0.006454                     0.120081
# YPR200C                       0.291845                     0.120081
# YPR204C-A                     0.187259                    -0.020342
#
#            data_Turco_expression_16248  data_Turco_expression_16249  \
# gene_id
# YAL002W                       0.120937                     0.127851
# YAL003W                       0.049383                    -0.085744
# YAL004W                       0.049383                    -0.085744
# YAL008W                       0.120937                     0.127851
# YAL009W                       0.120937                    -4.034924
# ...                                ...                          ...
# YPR195C                       0.049383                    -0.085744
# YPR197C                       0.049383                    -0.085744
# YPR199C                       0.120937                     0.127851
# YPR200C                       0.120937                     0.127851
# YPR204C-A                     0.049383                    -0.085744
#
#            data_Turco_expression_16250  data_Turco_expression_16683  \
# gene_id
# YAL002W                       0.128291                    -1.802252
# YAL003W                      -0.124338                     0.035694
# YAL004W                      -0.124338                     0.035694
# YAL008W                       0.128291                     1.086489
# YAL009W                       0.128291                     0.035502
# ...                                ...                          ...
# YPR195C                      -0.124338                     0.035694
# YPR197C                      -0.124338                     0.035694
# YPR199C                       0.128291                     1.170261
# YPR200C                       0.128291                     0.625506
# YPR204C-A                    -0.124338                     0.035694
#
#            data_Turco_expression_16684  data_Turco_expression_16685  \
# gene_id
# YAL002W                      -1.220942                    -0.876121
# YAL003W                       0.011140                     0.071771
# YAL004W                       0.011140                     0.071771
# YAL008W                       1.085078                     2.182672
# YAL009W                       0.011022                     0.071563
# ...                                ...                          ...
# YPR195C                       0.011140                     0.071771
# YPR197C                       0.011140                     0.071771
# YPR199C                       0.623874                     0.551316
# YPR200C                       0.162670                     0.755235
# YPR204C-A                     0.011140                     0.071771
#
#            data_Turco_expression_21888  data_Turco_expression_21932
# gene_id
# YAL002W                       0.854368                     1.492454
# YAL003W                      -0.280784                     0.324166
# YAL004W                      -0.280784                     0.324166
# YAL008W                       0.616041                     1.037160
# YAL009W                       0.298273                    -0.242586
# ...                                ...                          ...
# YPR195C                      -0.280784                     0.324166
# YPR197C                      -0.280784                     0.324166
# YPR199C                      -0.699168                    -0.390249
# YPR200C                      -1.114033                    -0.734796
# YPR204C-A                    -0.280784                     0.324166
#
# [6579 rows x 3023 columns]

# %%
X, y = preprocess_data_classification(embeddings, subfolder=True)

# %%
run_RandomForest_Classifier(X,y)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00       316
#            1       0.60      1.00      0.75      1184
#            2       0.44      0.02      0.03       500
#
#     accuracy                           0.59      2000
#    macro avg       0.35      0.34      0.26      2000
# weighted avg       0.46      0.59      0.45      2000
#
# [[   0  310    6]
#  [   0 1180    4]
#  [   0  492    8]]
# /opt/modules/i12g/anaconda/envs/ege_env/lib/python3.13/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /opt/modules/i12g/anaconda/envs/ege_env/lib/python3.13/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /opt/modules/i12g/anaconda/envs/ege_env/lib/python3.13/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))

# %%
run_XGBoost_Classifier(X,y)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.35      0.03      0.05       316
#            1       0.63      0.92      0.75      1184
#            2       0.44      0.23      0.30       500
#
#     accuracy                           0.60      2000
#    macro avg       0.47      0.39      0.37      2000
# weighted avg       0.54      0.60      0.53      2000
#
# [[   9  254   53]
#  [   7 1086   91]
#  [  10  377  113]]

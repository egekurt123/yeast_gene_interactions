# %%
from embedding_prediction_helpers import *

# %%
DNALM = pd.read_csv('../../extracted_data/yeast_emb_only_embeddings.csv', sep=',', index_col=0).set_index("gene_id")
DNALM_Genex = pd.read_csv('../../extracted_data/yeast_emb_embeddings_genex.csv', sep=',', index_col=0).set_index("gene_id")
DNALM_YeastNet = pd.read_csv('../../extracted_data/yeast_emb_embeddings_yeastnet.csv', sep=',', index_col=0).set_index("gene_id")
DNALM_YeastNet_Genex = pd.read_csv('../../extracted_data/yeast_emb_embeddings_yeastnet_genex.csv', sep=',', index_col=0).set_index("gene_id")

# %%
r2_dnalm = predict_all_models_double_holdout(DNALM, "DNALM", prediction_type="dmf")
# Out:
# Running for combination: DNALM
#
#
# Train interactions: 6455, Test interactions: 356
# Train genes: 4094, Test genes: 1023
# Linear Regression
# R2: -28.823
# RMSE: 1.370
#
#
# Train interactions: 6455, Test interactions: 356
# Train genes: 4094, Test genes: 1023
# Ridge Regression
# R2: 0.055
# RMSE: 0.244
#
#
# Train interactions: 6455, Test interactions: 356
# Train genes: 4094, Test genes: 1023
# XGBoost Regression
# R2: 0.043
# RMSE: 0.246
#
#
# Train interactions: 6455, Test interactions: 356
# Train genes: 4094, Test genes: 1023
# Random Forest Regression
# R2: 0.083
# RMSE: 0.240

# %%
r2_dnalm_yeastnet = predict_all_models_double_holdout(DNALM_YeastNet, "DNALM + YeastNet", prediction_type="dmf")
# Out:
# Running for combination: DNALM + YeastNet
#
#
# Train interactions: 6455, Test interactions: 356
# Train genes: 4094, Test genes: 1023
# Linear Regression
# R2: -16.701
# RMSE: 1.056
#
#
# Train interactions: 6455, Test interactions: 356
# Train genes: 4094, Test genes: 1023
# Ridge Regression
# R2: 0.036
# RMSE: 0.246
#
#
# Train interactions: 6455, Test interactions: 356
# Train genes: 4094, Test genes: 1023
# XGBoost Regression
# R2: 0.044
# RMSE: 0.245
#
#
# Train interactions: 6455, Test interactions: 356
# Train genes: 4094, Test genes: 1023
# Random Forest Regression
# R2: 0.091
# RMSE: 0.239

# %%
r2_dnalm_genex = predict_all_models_double_holdout(DNALM_Genex, "DNALM + Gene Expressions", prediction_type="dmf")
# Out:
# Running for combination: DNALM + Gene Expressions
#
#
# Train interactions: 6455, Test interactions: 356
# Train genes: 4094, Test genes: 1023
# Linear Regression
# R2: -26.788
# RMSE: 1.323
#
#
# Train interactions: 6455, Test interactions: 356
# Train genes: 4094, Test genes: 1023
# Ridge Regression
# R2: 0.177
# RMSE: 0.228
#
#
# Train interactions: 6455, Test interactions: 356
# Train genes: 4094, Test genes: 1023
# XGBoost Regression
# R2: 0.317
# RMSE: 0.207
#
#
# Train interactions: 6455, Test interactions: 356
# Train genes: 4094, Test genes: 1023
# Random Forest Regression
# R2: 0.306
# RMSE: 0.209

# %%
r2_dnalm_yeastnet_genex = predict_all_models_double_holdout(DNALM_YeastNet_Genex, "DNALM + YeastNet + Gene Expressions", prediction_type="dmf")
# Out:
# Running for combination: DNALM + YeastNet + Gene Expressions
#
#
# Train interactions: 6455, Test interactions: 356
# Train genes: 4094, Test genes: 1023
# Linear Regression
# R2: -16.592
# RMSE: 1.053
#
#
# Train interactions: 6455, Test interactions: 356
# Train genes: 4094, Test genes: 1023
# Ridge Regression
# R2: 0.162
# RMSE: 0.230
#
#
# Train interactions: 6455, Test interactions: 356
# Train genes: 4094, Test genes: 1023
# XGBoost Regression
# R2: 0.293
# RMSE: 0.211
#
#
# Train interactions: 6455, Test interactions: 356
# Train genes: 4094, Test genes: 1023
# Random Forest Regression
# R2: 0.297
# RMSE: 0.210

# %%
plot_r2_combinations(r2_dnalm, r2_dnalm_yeastnet, r2_dnalm_genex, r2_dnalm_yeastnet_genex)

# %%
from embedding_prediction_helpers import *

# %%
interaction_table
# Out:
#         query_gene array_gene  gi_score
# 0          YAL001C    YBL023C   -0.0348
# 1          YAL001C    YBL026W   -0.3529
# 2          YAL001C    YBL076C   -0.0250
# 3          YAL001C    YBL097W   -0.0808
# 4          YAL001C    YBR029C   -0.1173
# ...            ...        ...       ...
# 1122249    YPR202W    YOR262W   -0.1490
# 1122250    YPR202W    YPL007C   -0.0572
# 1122251    YPR202W    YPL076W    0.0695
# 1122252    YPR202W    YPL169C    0.0567
# 1122253    YPR202W    YPR055W    0.0437
#
# [1122254 rows x 3 columns]

# %% [markdown]
# ## Used Embeddings : DNALM
# - sequence features
# - lm_3utr_emb
# - lm_5utr_emb
# - protein embeddings

# %%
embeddings = pd.read_csv('../../extracted_data/yeast_emb_embeddings_genex_orthogroup.csv', sep=',', index_col=0)
embeddings = embeddings.set_index('gene_id')
embeddings
# Out:
#            gc_5_prime  gc_3_prime    gc_cds       AAA       AAC       AAG  \
# gene_id
# YAL002W      0.365902    0.310000  0.372057  0.043956  0.019623  0.018053
# YAL003W      0.372881    0.253333  0.448220  0.009709  0.024272  0.077670
# YAL004W      0.417747    0.346667  0.451163  0.023256  0.023256  0.000000
# YAL008W      0.381854    0.296667  0.388889  0.045455  0.020202  0.040404
# YAL009W      0.368893    0.323333  0.414414  0.042471  0.011583  0.023166
# ...               ...         ...       ...       ...       ...       ...
# YPR195C      0.334995    0.393333  0.467890  0.027523  0.000000  0.000000
# YPR197C      0.376869    0.276667  0.374332  0.058824  0.021390  0.021390
# YPR199C      0.329013    0.283333  0.391156  0.030612  0.020408  0.047619
# YPR200C      0.366899    0.313333  0.376923  0.038462  0.015385  0.038462
# YPR204C-A    0.402189    0.426667  0.454167  0.031250  0.018750  0.000000
#
# ...

# %%
X, y = preprocess_data(interaction_table, embeddings)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 X, y = preprocess_data(interaction_table, embeddings)
#
# File ~/yeast_gene_interactions/Table Predictions/from_embeddings/embedding_prediction_helpers.py:25, in preprocess_data(interaction_table, embeddings)
#      17 filtered = interaction_table[
#      18     interaction_table['query_gene'].isin(available_genes) &
#      19     interaction_table['array_gene'].isin(available_genes)
#      20 ].copy()
#      22 filtered_sample = filtered.sample(n=10000, random_state=42)
#      24 X = np.array([
# ---> 25     np.concatenate([embeddings.loc[row['query_gene']].values,
#      26                     embeddings.loc[row['array_gene']].values])
#      27     for _, row in filtered_sample.iterrows()
#      28 ])
#      31 y = filtered_sample['gi_score'].values
#      33 return X, y
#
# ...

# %% [markdown]
# ## Linear Regression

# %%
run_Linear_Regression(X, y, "darkblue")

# %%
X_PCA = run_PCA(X)
# Out:
# 0.8190775832935094

# %% [markdown]
# ## Linear Regression with PCA

# %%
run_Linear_Regression(X_PCA, y, "darkred")
# Out:
# R2:  0.0034074255258750297
# RMSE: 0.13111134166359725

# %% [markdown]
# ## XGBoost

# %%
run_XGBoost(X, y)
# Out:
# XGBoost R² score: -0.046
# XGBoost RMSE: 0.135

# %% [markdown]
# ## RandomForests

# %%
run_Random_Forest(X, y, embeddings)
# Out:
# Random Forest R² score: 0.002
# Random Forest RMSE: 0.131
